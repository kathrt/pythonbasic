# %% [markdown]
# 數字做圖

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
tan(pi/2)
# Out:
# 1.633123935319537e+16

# %%
plot([3,9,-80,96,12,-32,54,0])

# %%
randn(100)
# Out:
# array([ 0.86513973,  0.90429065, -0.53792138, -1.10548745,  1.36155036,
#        -0.62482997,  0.39380612, -0.79988563,  0.91498648,  0.4155915 ,
#         0.31846309, -0.31301683, -0.58126026,  2.29012579,  0.5880737 ,
#         1.58160718, -0.67414794, -1.59463764,  0.76982883,  0.17606979,
#        -0.32031637,  1.94072419,  0.11528786, -1.75275402, -0.31462904,
#        -0.25406925,  0.8697159 , -0.39916646,  0.17507041,  0.24570986,
#        -1.22631794,  0.35451784,  0.48906537, -0.53555552, -2.24774841,
#         0.41447093, -0.19826859, -0.37405369, -0.7183842 ,  0.19258945,
#         0.41230402,  0.58158389,  1.14897502, -0.72901486, -0.51400729,
#        -1.57488423,  0.65172068,  0.27463795, -0.41278752, -0.75027736,
#        -0.05471114, -0.18652496,  0.55845719,  1.80396407,  0.15529517,
#        -0.03477792, -0.30636542, -0.99178325, -0.50977194,  0.88016531,
#         0.21877867, -0.61863073,  1.6675699 ,  0.09701889,  0.0386642 ,
# ...

# %%
plot(randn(100))

# %%
plot([0,5,2,4,7,346,-14,-35,925,-25],[3,5,368,-74,-7437,3685,364,0,534,-6])

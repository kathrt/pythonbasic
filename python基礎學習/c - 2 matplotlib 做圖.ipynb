# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.random.rand(50)

# %%
y
# Out:
# array([0.91653682, 0.34347307, 0.5663996 , 0.03035505, 0.62435711,
#        0.75155087, 0.68787856, 0.6701469 , 0.08137354, 0.77103427,
#        0.24255029, 0.59634621, 0.90541808, 0.31370203, 0.80442726,
#        0.85760109, 0.17927997, 0.91630512, 0.04026991, 0.11594803,
#        0.48193635, 0.61305563, 0.20019519, 0.75095452, 0.71247999,
#        0.45700358, 0.5929279 , 0.46792449, 0.62595272, 0.1440214 ,
#        0.19837441, 0.19898375, 0.9877306 , 0.26350535, 0.26875278,
#        0.23102191, 0.65790939, 0.14346434, 0.56565258, 0.43584314,
#        0.2715781 , 0.91621613, 0.69123009, 0.2838796 , 0.65055892,
#        0.82397131, 0.77850524, 0.37239734, 0.62361127, 0.65009828])

# %%
plt.plot(y)

# %% [markdown]
# ###### 描點 x = np.linspace ( 起始點 , 終點 , 點的數量 )

# %%
x = np.linspace(0,10,100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x,np.sin(x))

# %%
plt.plot(x,np.sin(x)+x)
plt.plot(y,np.cos(y))

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
L = np.array([3,-2,4,60,-73,59])

# %%
L < 0
# Out:
# array([False,  True, False, False,  True, False])

# %%
L[0]
# Out:
# 3

# %%
L[2:4]
# Out:
# array([ 4, 60])

# %%
L[L<0]
# Out:
# array([ -2, -73])

# %%
x = np.linspace(-5,5,500)
y = np.sinc(x)

plt.plot(x,y)

# %%
plt.plot(x,y)
plt.plot(x[y>0], y[y>0], 'o')

# %%
s = np.linspace(0, 10, 5)
plt.figure(figsize = (12, 8))
plt.plot(s, np.e**(s), 'o')
plt.plot(x, np.e**(x),'g', label = 'e^(x)')
plt.title('teamwork')
plt.xlabel('x')
plt.ylabel('e^(x)')
plt.grid()
plt.legend(loc='lower right')
plt.show()

# %%
s = np.linspace(0, 1, 10)
plt.figure(figsize = (12, 8))
plt.plot(s, np.e**(s), 'o')
plt.plot(x, np.e**(x),'g', label = 'e^(x)')
plt.title('teamwork')
plt.xlabel('x')
plt.ylabel('e^(x)')
plt.grid()
plt.legend(loc='lower right')
plt.show()

# %%
s = np.linspace(0, 10, 20)
plt.figure(figsize = (12, 8))
plt.plot(s, np.e**(s), 'o')
plt.plot(x, np.e**(x),'g', label = 'e^(x)')
plt.title('teamwork')
plt.xlabel('x')
plt.ylabel('e^(x)')
plt.grid()
plt.legend(loc='lower right')
plt.show()

# %%
s = np.linspace(0, 10, 5)
plt.figure(figsize = (12, 8))
plt.plot(s, np.e**(s), 'o')
plt.plot(x, np.e**(x),'g', label = 'e^(x)')
plt.title('teamwork')
plt.xlabel('x')
plt.ylabel('e^(x)')
plt.grid()
plt.legend(loc='lower right')
plt.show()

# %%
plt.subplot(2, 2, 1)
a = np.linspace(0.2, 10, 5)
plt.plot(a, np.e**(a), 'o')
plt.plot(x, np.e**(x))
plt.title('h = 0.2')
plt.xlabel('x')
plt.ylabel('e^(x)')
plt.grid()

plt.subplot(2, 2, 2)
b = np.linspace(0.1, 10, 10)
plt.plot(b, np.e**(b), 'o')
plt.plot(x, np.e**(x))
plt.title('h = 0.1')
plt.xlabel('x')
plt.ylabel('e^(x)')
plt.grid()

plt.subplot(2, 2, 3)
c = np.linspace(0.05, 10, 20)
plt.plot(c, np.e**(c), 'o')
plt.plot(x, np.e**(x))
plt.title('h = 0.05')
plt.xlabel('x')
plt.ylabel('e^(x)')
plt.grid()
plt.show()

# %%
def y(x):
    return y(x) + 0,2*(np.e**(x))
